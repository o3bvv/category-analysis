# %%
import operator 
import re

from collections.abc import Iterable
from collections.abc import Generator
from collections.abc import Callable

from typing import Any

import contractions
import pandas as pd

from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from stop_words import get_stop_words

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

from catalog import load_catalog

# %%
catalog = load_catalog()

# %%
def get_title(node: dict) -> str:
  return node['data']['title']


def format_title_leveled(title: str, depth: int) -> str:
  return ' ' * (depth - 1) + title


def get_title_callback(node: dict, *args) -> str:
  return get_title(node)

# %%
def traverse_catalog(
  catalog:   Iterable[dict],
  callback:  Callable[[dict, int], Any] | None = None,
  max_depth: int | None = None,
) -> Generator[str, None, None]:    

  def visit(node: dict, depth: int = 1):
    yield callback(node, depth)

    if max_depth is not None and depth >= max_depth:
      return

    children = node.get('children')
    if children:
      depth += 1
      for child in children:
        yield from visit(child, depth)    
  
  for tree in catalog:
    yield from visit(tree)

# %%
def count_chars(strings: Iterable[str]) -> dict[str, int]:  
  chars = dict()

  for s in strings:
    for ch in s:
      chars[ch] = chars.setdefault(ch, 0) + 1

  return chars

# %%
df_chars_original = pd.DataFrame.from_records(
  data    = list(count_chars(traverse_catalog(catalog, callback=get_title_callback)).items()),
  columns = ('char', 'n'),
)
df_chars_original[
     (df_chars_original['char'] < 'A')
  | ((df_chars_original['char'] > 'Z') & (df_chars_original['char'] < 'a'))
  |  (df_chars_original['char'] > 'z')
].sort_values('n', ascending=False)
# Out:
#    char     n
# 8        5700
# 17    &  1032
# 43    :   271
# 37    ,   269
# 42    -   117
# 61    0   115
# 50    (    91
# 51    )    91
# 21    /    80
# 58    1    50
# 64    '    23
# 67    5    16
# 59    2    15
# 69    9    14
# 65    6    10
# 68    8     8
# 60    3     8
# 66    7     6
# 70    4     5
# 62    .     1

# %%
REMOVE_REGEX_PATTENS_1 = re.compile("(%s)" % "|".join([
  r"[&,()]",
  r"\betc\b",
  r"\beg\b",
  r"\be.g.\b",  
  r"\bc \d+(/\d+)? (ce|bce)\b",
  r"\b\d+(/\d+)? (ce|bce)\b",
  r"\bc \d+(/\d+)?\b",
  r"\W+$",
]))

SPACE_REGEX_PATTENS = re.compile("(%s)" % "|".join([
  r"[/:]",
  r"\s+\-\s+",  
]))

REPLACE_REGEX_PATTERNS = (
  (re.compile(r"\belt\b"), "english language teaching"),
  (re.compile(r"\bya\b"),  "young adult"),
  (re.compile(r"\br'n'b\b"),  "rnb"),
)

REMOVE_REGEX_PATTENS_2 = re.compile("(%s)" % "|".join([
  r"[']",
]))


STOP_WORDS = set(stopwords.words("english")) | set(get_stop_words('en'))

def is_stop_word(s: str) -> bool:
  return s in STOP_WORDS


SPLIT_TOKEN_REGEX = re.compile(r"[-_]")

def split_token(s: str) -> Iterable[str]:
  return SPLIT_TOKEN_REGEX.split(s)


def clean_title(s: str) -> str:
  s = s.lower()
  s = REMOVE_REGEX_PATTENS_1.sub("", s)
  s = SPACE_REGEX_PATTENS.sub(" ", s)
  
  for pattern, sub in REPLACE_REGEX_PATTERNS:
    s = pattern.sub(sub, s)

  s = contractions.fix(s)  
  s = REMOVE_REGEX_PATTENS_2.sub("", s)

  t = []
  x_prev = None

  for x in word_tokenize(s):
    if not is_stop_word(x) and x != x_prev:
      t.append(x)
      x_prev = x

  return " ".join(t)

# %%
for s in traverse_catalog(
  catalog,
  callback  = lambda x, d: format_title_leveled(clean_title(get_title(x)), d),
  max_depth = 3,
):
  print(s)
# Out:
# medical
#  medicine
#   medical profession
#   medical equipment techniques
#   public health preventive medicine
#   health systems services
#   medicolegal issues
#   medical sociology
#   history medicine
#  pre-clinical medicine basic sciences
#   anatomy
#   physiology
#   human reproduction growth development
#   medical genetics
#  clinical internal medicine
#   medical diagnosis
#   diseases disorders
#   cardiovascular medicine
#   musculoskeletal medicine
#   haematology
#   endocrinology
#   gastroenterology
#   hepatology
#   dermatology
#   respiratory medicine
#   rheumatology
#   neurology clinical neurophysiology
#   otorhinolaryngology ent
#   ophthalmology
#   renal medicine nephrology
#   urology urogenital medicine
#   gynaecology obstetrics
#   paediatric medicine
#   geriatric medicine
#   gene therapy
#  branches medicine
#   anaesthetics
#   palliative medicine
#   dentistry
#   pathology
#   pharmacology
#   psychiatry
#   clinical psychology
#   accident emergency medicine
#   nuclear medicine
#   medical imaging
#   forensic medicine
#   environmental medicine
#   sports injuries medicine
#   therapy therapeutics
#  surgery
#   surgical techniques
#   general surgery
#   gastrointestinal colorectal surgery
#   cardiothoracic surgery
#   vascular surgery
#   surgical oncology
#   critical care surgery
#   neurosurgery
#   plastic reconstructive surgery
#   transplant surgery
#   orthopaedics fractures
#   peri-operative care
#  nursing ancillary services
#   nursing
#   midwifery
#   first aid paramedical services
#   radiography
#   chiropody podiatry
#   pharmacy dispensing
#   optometry opticians
#   physiotherapy
#   occupational therapy
#   medical counselling
#   rehabilitation
#   biomedical engineering
#   mortuary practice
#  medical study revision guides reference material
#   medical study revision guides
#   medical charts colour atlases
#  complementary medicine
#   chiropractic osteopathy
#  veterinary medicine
#   veterinary medicine small animals pets
#   veterinary medicine large animals domestic farm
#   veterinary medicine laboratory animals
#   veterinary medicine exotic zoo animals
#   veterinary anatomy physiology
#   veterinary pathology histology
#   veterinary nutrition
#   veterinary medicine infectious diseases therapeutics
#   veterinary pharmacology
#   veterinary radiology
#   veterinary surgery
#   veterinary dentistry
#   veterinary nursing
#   complementary medicine animals
# science geography
#  mathematics
#   philosophy mathematics
#   mathematical foundations
#   discrete mathematics
#   algebra
#   groups group theory
#   number theory
#   pre-calculus
#   calculus mathematical analysis
#   geometry
#   topology
#   probability statistics
#   optimization
#   combinatorics graph theory
#   applied mathematics
#   history mathematics
#  science general issues
#   philosophy science
#   scientific nomenclature classification
#   scientific standards
#   maths scientists
#   industrial applications scientific research technological innovation
#   science funding policy
#   scientific equipment experiments techniques
#   impact science technology society
#   history science
#   popular science
#  astronomy space time
#   theoretical mathematical astronomy
#   astronomical observation observatories equipment methods
#   cosmology universe
#   galaxies stars
#   solar system sun planets
#   astronomical charts atlases
#   time chronology time systems standards
#  physics
#   classical mechanics
#   states matter
#   thermodynamics heat
#   light optics
#   electricity electromagnetism magnetism
#   atomic molecular physics
#   nuclear structure physics
#   particle high-energy physics
#   quantum physics quantum mechanics quantum field theory
#   relativity physics
#   statistical physics
#   mathematical physics
#   applied physics
#  chemistry
#   analytical chemistry
#   inorganic chemistry
#   organic chemistry
#   physical chemistry
#   crystallography
#   mineralogy gems
#  biology life sciences
#   life sciences general issues
#   biochemistry
#   developmental biology
#   molecular biology
#   cellular biology cytology
#   microbiology non-medical
#   hydrobiology
#   mycology fungi non-medical
#   botany plant sciences
#   zoology animal sciences
#   human biology
#  earth sciences geography environment planning
#   earth sciences
#   geography
#   environment
#   regional area planning
# technology engineering
#  technology general issues
#   engineering general
#   technical design
#   engineering graphics technical drawing
#   maths engineers
#   instruments instrumentation engineering
#   nanotechnology
#   intermediate technology
#   history engineering technology
#   inventions inventors
#  biochemical engineering
#   biotechnology
#  industrial chemistry manufacturing technologies
#   industrial chemistry
#   leather fur technology
#   textile fibre technology
#   timber wood processing
#   metals technology metallurgy
#   manufacturing technologies
#  mechanical engineering materials
#   mechanical engineering
#   materials science
#   production engineering
#   engineering skills trades
#  energy technology engineering
#   fossil fuel technologies
#   nuclear power engineering
#   heat transfer processes
#   electrical engineering
#   alternative renewable energy sources technology
#  electronics communications engineering
#   electronics engineering
#   communications engineering telecommunications
#  civil engineering surveying building
#   structural engineering
#   hydraulic engineering
#   highway traffic engineering
#   building construction materials
#   building skills trades
#  environmental science engineering technology
#   environmental monitoring
#   pollution control
#   sanitary municipal engineering
#  transport technology trades
#   automotive technology trades
#   railway technology engineering trades
#   shipbuilding technology engineering trades
#   aerospace aviation technology
#   intelligent automated transport system technology
#  technologies applied sciences
#   acoustic sound engineering
#   applied optics
#   space science
#   military engineering
#   explosives technology pyrotechnics
#   marine engineering
#   mining technology engineering
#   vocational technologies trades
#   taxidermy
#  agriculture farming
#   agricultural science
#   agricultural engineering machinery
#   sustainable agriculture
#   organic farming
#   animal husbandry
#   agronomy crop production
#   smallholdings
#   pest control
#   tropical agriculture practice techniques
#   forestry silviculture practice techniques
#   horticulture
#   aquaculture fish-farming practice techniques
# computing
#  computing general
#   health safety aspects computing
#   ethical social aspects computing
#   legal aspects computing
#  digital lifestyle
#   internet guides online services
#   email consumer user guides
#   pdas handheld devices consumer user guides
#   digital music consumer user guides
#   digital photography consumer user guides
#   digital video consumer user guides
#   mobile phones consumer user guides
#   digital tv media centres consumer user guides
#  games strategy guides
#  business applications
#   integrated software packages
#   spreadsheet software
#   word processing software
#   presentation graphics software
#   accounting software
#   enterprise software
#   mathematical statistical software
#   project management software
#   collaboration group software
#  graphical digital media applications
#   web graphics design
#   computer-aided design cad
#   desktop publishing
#   computer games design
#   3d graphics modelling
#   illustration drawing software
#   digital music professional
#   digital animation
#   photo image editing
#   digital video professional
#  computer hardware
#   supercomputers
#   mainframes minicomputers
#   servers
#   grid parallel computing
#   embedded systems
#   network hardware
#   personal computers
#   maintenance repairs
#   storage media peripherals
#   utilities tools
#  operating systems
#   microsoft windows
#   macintosh os
#   linux
#   unix
#   handheld operating systems
#   ibm mainframe operating systems
#   real time operating systems
#  computer programming software development
#   program concepts learning program
#   algorithms data structures
#   compilers
#   agile programming
#   aspect programming aop
#   extreme programming
#   functional programming
#   games development programming
#   graphics programming
#   object-oriented programming oop
#   microsoft programming
#   macintosh programming
#   network programming
#   pda handheld programming
#   database programming
#   web programming
#   programming scripting languages general
#   software engineering
#  databases
#   database design theory
#   data capture analysis
#   data warehousing
#   data mining
#   information retrieval
#   object-oriented databases
#   distributed databases
#   databases web
#   database software
#  computer certification
#   computer certification microsoft mcse
#   computer certification cisco
#   computer certification ecdl
#   computer certification comptia
#   computer certification clait
#  computer security
#   privacy data protection
#   computer fraud hacking
#   computer viruses trojans worms
#   firewalls
#   spam
#   spyware
#   data encryption
#  computer networking communications
#   client-server networking
#   network management
#   grid computing
#   electronic mail email professional
#   network security
#   networking standards protocols
#   distributed systems
#   networking packages
#   wap networking applications
#   edi electronic data interchange
#  computer science
#   mathematical theory computation
#   systems analysis design
#   computer architecture logic design
#   artificial intelligence
#   signal processing
#   image processing
#   audio processing
#   virtual reality
#   human-computer interaction
# art photography
#  architecture
#   theory architecture
#   individual architects architectural firms
#   architectural structure design
#   architecture professional practice
#   public buildings civic commercial industrial
#   residential buildings domestic buildings
#   religious buildings
#   professional interior design
#   landscape art architecture
#   history architecture
#  theatre studies
#   theatre individual actors directors
#   acting techniques
#   theatre direction production
#   theatre technical background skills
#   theatre management
#  entertainment
#   individual actors performers
#   films cinema
#   television
#   radio
#  dance performing arts
#   dance
#   performing arts
#  music
#   theory music musicology
#   music reviews criticism
#   discographies buyers guides
#   music styles genres
#   individual composers musicians specific bands groups
#   musical scores lyrics libretti
#   musical instruments instrumental ensembles
#   techniques music tutorials
#   music recording reproduction
#  general
#   art theory
#   art resoration
#   forgery
#   art finance
#  art forms
#   paintings
#   drawing
#   prints
#   graphic art
#   non-graphic art forms
#   pottery glassware
#   decorative arts
#   textile artworks
#   body art tattooing
#  art treatments subjects
#   individual artists art monographs
#   exhibition catalogues specific collections
#   human figures depicted art
#   small-scale secular domestic scenes art
#   animals nature art still life landscapes seascapes
#   man-made objects depicted art cityscapes machines
#   religious subjects depicted art
#   art techniques principles
#  art history
#   art history pre-history
#   art history ancient classical bce
#   art history byzantine medieval
#   art history
#   art history
#   art history
#   art history
#   styles
#  photography
#   individual photographers
#   photographs collections
#   photographic equipment techniques
#   special kinds photography
#  industrial commercial art design
#   product design
#   furniture design
#   fashion textiles design
#   individual designers
#   graphic design
#   typography lettering
#   illustration commercial art
# biography
#  biography general
#   autobiography general
#   biography business industry
#   biography arts entertainment
#   biography historical political military
#   biography literary
#   biography royalty
#   biography sport
#   biography science technology engineering
#   biography religious spiritual
#  diaries letters journals
#  memoirs
#  true stories
#   true crime
#   true stories discovery historical scientific
#   true war combat stories
#   true stories heroism endurance survival
#   erotic confessions true stories
# dictionaries languages
#  language reference general
#   creative writing creative writing guides
#   writing editing guides
#   language history general works
#  dictionaries
#   bilingual multilingual dictionaries
#  thesauri
#  usage grammar guides
#  public speaking guides
#  linguistics
#   philosophy language
#   sociolinguistics
#   literacy
#   psycholinguistics
#   historical comparative linguistics
#   semantics
#   phonetics phonology
#   grammar syntax
#   palaeography history writing
#   lexicography
#   translation interpretation
#   computational linguistics
#   sign languages braille linguistic communication
#  language teaching learning english language teaching
#   language teaching theory methods
#   language teaching learning material coursework
#   language learning specific skills
#  english language teaching background reference material
#   english language teaching theory methods
#   english language teaching dictionaries reference
#  english language teaching learning material coursework
#   english language teaching grammar vocabulary
#   english language teaching graded readers
#   english language teaching non-book material resources
#   english language teaching workbooks practice books exercises
#   english language teaching self-study texts
#   english language teaching examination practice tests
#   english language teaching specific skills
#  english language teaching english specific purposes
#   english language teaching english business
#   english language teaching english academic purposes
#   english language teaching english technical scientific purposes
#   english language teaching english travel communications
#  language phrasebooks
# crime thriller
#  crime
#   vintage crime
#   historical crime
#  thrillers
#   espionage
#   political legal
#  true crime
# science fiction fantasy horror
#  horror
#   classic horror
#  science fiction
#   classic science fiction
#   space opera
#  fantasy
# romance
#  adult contemporary romance
#  historical romance
# history archaeology
#  history theory methods
#   historiography
#  general world history
#  regional national history
#   european history
#   asian history
#   african history
#   history americas
#   australasian pacific history
#   history lands
#  history earliest times present day
#   ancient history
#   early history
#   early modern history
#   modern history 20th century
#   20th century history
#   21st century history
#  history specific events topics
#   social cultural history
#   oral history
#   genealogy heraldry names honours
#   industrialisation industrial history
#   maritime history
#   historical geography
#   colonialism imperialism
#   national liberation independence post-colonialism
#   slavery abolition slavery
#   revolutions uprisings rebellions
#   cold war
#   genocide ethnic cleansing
#  military history
#   crusades
#   english civil war
#   american war independence
#   napoleonic wars
#   american civil war
#   crimean war
#   boer wars
#   first world war
#   spanish civil war
#   second world war
#   military history post ww2 conflicts
#  archaeology
#   archaeological theory
#   archaeology period region
#   landscape archaeology
#   environmental archaeology
#   underwater archaeology
#   industrial archaeology
#   archaeological methodology techniques
#  local history genealogy
#   local history
#   nostalgia general
#   photographic
#   genealogy
# health
#  safety home
#  popular medicine health
#   first aid home
#   mens health
#   womens health
#  home nursing caring
#  coping personal problems
#   coping illness
#   coping disability
#   coping old age
#   coping eating disorders
#   coping drug alcohol abuse
#   coping anxiety phobias
#   coping stress
#   coping death bereavement
#  giving smoking
#  fitness diet
#   diets dieting
#   exercise workout books
#   massage
#  family relationships
#   sex sexuality sex manuals
#   dating relationships living together marriage
#   adoption
#   separation divorce
#   intergenerational relationships
#  advice parenting
#   pregnancy birth baby care
#   child care upbringing
# personal development
#  personal finance
#  advice careers achieving success
#  law lay person
#  roadcraft driving highway code
#  consumer advice
#  housing property individual buying selling legal aspects
#  advice education
#  adult literacy guides handbooks
#  adult numeracy guides handbooks
#  popular psychology
#   assertiveness motivation self-esteem
#   memory improvement thinking techniques
#   neuro linguistic programming nlp
#  retirement
#  living working abroad
#  self-sufficiency
# mind body spirit
#  mind body spirit thought practice
#  fortune-telling divination
#   astrology
#   fortune-telling cards cartomancy
#   ching
#   graphology
#   palmistry phrenology physiognomy
#   numerology
#   clairvoyance precognition
#  complementary therapies healing health
#   alexander technique
#   aromatherapy essential oils
#   homoeopathy
#   reflexology
#   reiki
#   traditional medicine herbal remedies
#  mind body spirit meditation visualisation
#  dreams interpretation
#  psychic powers psychic phenomena
#   crystals colour-healing
#   chakras auras spiritual energy
#   astral projection out-of-body experiences
#   reincarnation past lives
#   spirit guides angels channelling
#  unexplained phenomena paranormal
#   ufos extraterrestrial beings
#   ghosts poltergeists
#   monsters legendary beings
#  feng shui
#  mysticism magic ritual
#   kabbalah popular works
#   magic spells alchemy
#   shamanism paganism druidry
#   witchcraft wicca
# poetry drama
#  poetry
#   poetry individual poets
#   poetry anthologies various poets
#  plays playscripts
#   shakespeare plays
#  prose non-fiction
#   literary essays
#   reportage collected journalism
#  anthologies non-poetry
#  literature history criticism
#   literary theory
#   literary studies general
#   literary studies poetry poets
#   literary studies plays playwrights
#   literary studies fiction novelists prose writers
#   literary reference works
#   childrens literature studies general
# food drink
#  general cookery
#  celebrity chefs
#  cooking one
#  quick easy cooking
#  health wholefood cookery
#   cookery dietary conditions
#  vegetarian cookery
#  national regional cuisine
#  cooking children
#  cooking parties
#  cooking specific gadgets
#  cookery ingredient
#   cooking meat game
#   cooking chicken poultry
#   cooking fish seafood
#   cooking herbs spices
#   pasta dishes
#   cooking dairy products
#   cooking chocolate
#  cookery dishes courses
#   soups starters
#   salads
#   main courses
#   desserts
#   cakes baking icing sugarcraft
#  preserving freezing
#  beverages
#   alcoholic beverages
#   non-alcoholic beverages
#  cigars smoking
# home garden
#  antiques collectables
#   antiques collectables buyers guides
#   care restoration antiques
#   coins banknotes medals seals numismatics
#   stamps philately
#   antique clocks watches musical boxes automata
#   militaria arms armour
#   antique furniture collecting
#   antiques collectables ceramics glass
#   antiques collectables jewellery
#   antiques collectables gold silver jewellery
#   antiques collectables books manuscripts ephemera printed matter
#   antiques collectables pictures prints maps
#   antiques collectables carpets rugs textiles
#   antiques collectables toys games models
#   antiques collectables scientific musical instruments
#  style guides
#   fashion style guides
#   cosmetics hair beauty
#   interior design decor style guides
#   shopping guides
#   weddings wedding planners
#   parties etiquette entertaining
#  diy general
#   diy house maintenance manuals
#   diy carpentry woodworking
#  household hints
#  home renovation extension
#  gardening
#   gardens descriptions history
#   garden design planning
#   greenhouses conservatories patios
#   gardening plants
#   specialized gardening methods
#   allotments
# crafts hobbies
#  hobbies games
#  painting art manuals
#  needlework fabric crafts
#   embroidery crafts
#   lace lacemaking
#   quiltmaking patchwork applique
#   knitting crochet
#   batik tie-dye
#  ropework knots macrame
#  rug carpetmaking
#  spinning weaving
#  toys making decorating
#  jewellery beadcraft
#  decorative finishes surfaces
#  decorative wood metalwork
#   picture framing
#  pottery ceramics glass crafts
#  carving modelling moulding casting
#  book paper crafts
#   greeting cards
#   origami paper engineering
#   scrapbook keeping
#  lettering calligraphy
#  rural crafts
#  flower arranging floral crafts
# transport
#  road motor vehicles
#   motor cars
#   buses trams commercial
#   motorcycles
#   tractors farm
#   maintenance repair
#  trains railways
#  ships shipping
#   narrowboats canals
#  aircraft
# humour
#  cartoons comic strips
#  tv tie-in humour
#  jokes riddles
#  slang dialect humour
#  parodies spoofs
#  humour collections anthologies
# natural history
#  dinosaurs prehistoric world
#  wildlife general interest
#   wildlife birds birdwatching
#   wildlife mammals
#   wildlife reptiles amphibians
#   wildlife butterflies insects spiders
#   wildlife aquatic creatures
#  countryside country life
#  farm working animals
#  domestic animals pets
#   cats pets
#   dogs pets
#   fishes aquaria
#   horses ponies
#   birds including cage birds pets
#   rabbits rodents pets
#   reptiles amphibians pets
#   insects spiders pets
#  zoos wildlife parks
#  trees wildflowers plants
#  rocks minerals fossils
#  earth natural history general
#   weather
#  popular astronomy space
# sport
#  events organisations
#   olympic games
#   sports governing bodies
#   teams clubs
#   sporting venues
#  training coaching
#   sports psychology
#   drug abuse sport
#  extreme sports
#  air sports recreations
#  ball games
#   football soccer association football
#   cricket
#   rugby football
#   golf
#   hockey
#   lacrosse
#   hurling
#   gaelic football
#   basketball
#   netball
#   australian rules football
#   racket games
#   american football
#   baseball
#   volleyball
#   bowls bowling petanque
#   snooker billiards pool
#  track field sports athletics
#   marathon cross-country running
#   multidiscipline sports
#  gymnastics
#  weightlifting
#  equestrian animal sports
#   horse racing
#   riding showjumping horsemanship
#   greyhound racing
#  motor sports
#   car racing
#   motor rallying rally driving
#   motorcycle racing
#  cycling
#  rollerblading skateboarding
#  water sports recreations
#   swimming diving
#   surfing windsurfing water skiing
#   boating
#  combat sports self-defence
#   boxing
#   wrestling
#   fencing
#   oriental martial arts
#  bodybuilding
#  winter sports
#   skiing
#   snowboarding
#   ice-skating
#   ice hockey
#  field sports fishing hunting shooting
#   fishing angling
#   hunting shooting animals game
#   archery
#   small firearms guns equipment
#   target shooting
#  active outdoor pursuits
#   walking hiking trekking
#   climbing mountaineering
#   orienteering
#   caving potholing
#   camping woodcraft
#   outdoor survival skills
# travel holiday guides
#  tips advice
#  guidebooks
#   adventure holidays
#   business travel
#   eco-tourist guides
#   travel children family holidays
#   hotel holiday accommodation guides
#   museum historic sites gallery art guides
#   restaurant cafe pub guides
#   theme parks funfairs
#   cruises
#  language phrasebooks
#  travel writing
#   classic travel writing
#   expeditions
#  places peoples pictorial works
#  travel maps atlases
#   road atlases
#   travel maps
#   street maps city plans
#  world atlases world maps
# religion
#  religion general
#   philosophy religion
#   comparative religion
#   interfaith relations
#   religious issues debates
#   history religion
#  christianity
#   historical jesus
#   christian churches denominations
#   bibles
#   biblical studies exegesis
#   ecumenism
#   christian liturgy prayerbooks hymnals
#   christian theology
#   christian sermons
#   christian worship rites ceremonies
#   christian spirituality religious experience
#   christian life practice
#   christian institutions organizations
#   christian quasi-christian cults sects
#  buddhism
#   buddhist worship rites ceremonies
#   buddhist life practice
#   buddhist sacred texts
#   tibetan buddhism
#   zen buddhism
#  hinduism
#   hindu worship rites ceremonies
#   hindu life practice
#   hindu sacred texts
#  islam
#   islamic worship rites ceremonies
#   islamic life practice
#   koran
#   islamic theology
#   sufism islamic mysticism
#  judaism
#   judaism worship rites ceremonies
#   judaism life practice
#   judaism sacred texts
#   judaism theology
#   judaism mysticism
#  non-christian religions
#   bahai
#   jainism
#   oriental religions
#   ancient religions mythologies
#   sikhism
#   tribal religions
#   zoroastrianism
#  aspects religion non-christian
#   theology
#   sacred texts
#   prayers liturgical material
#   worship rites ceremonies
#   spirituality religious experience
#   religious life practice
#   religious institutions organizations
#  alternative belief systems
#   humanist secular alternatives religion
#   eclectic esoteric religions belief systems
#   contemporary non-christian para-christian cults sects
#   occult studies
# entertainment
#  individual actors performers
#  films cinema
#   film theory criticism
#   individual film directors film-makers
#   film scripts screenplays
#   film guides reviews
#   film styles genres
#   documentary films
#   animated films
#   film production technical background skills
#  television
#   television scripts screenplays
#   television soap operas
#   television production technical background skills
#  radio
#   radio scripts
#  dance performing arts
#   dance
#   performing arts
#  music
#   theory music musicology
#   music reviews criticism
#   discographies buyers guides
#   music styles genres
#   individual composers musicians specific bands groups
#   musical scores lyrics libretti
#   musical instruments instrumental ensembles
#   techniques music tutorials
#   music recording reproduction
# teaching resources education
#  philosophy theory education
#   moral social purpose education
#  educational psychology
#  educational strategies policy
#   literacy strategies
#   numeracy strategies
#   inclusive education mainstreaming
#   multicultural education
#  education care counselling students
#   bullying anti-bullying strategies
#   truancy anti-truancy strategies
#   exclusions dropping school
#  organization management education
#   admissions procedures
#   curriculum planning development
#   examinations assessment
#   schools inspection preparing inspection
#   funding education student finance
#   teaching staff
#   non-teaching support staff
#   school community relations school home relations
#   school governors school boards
#   students student organisations
#  schools
#   pre-school kindergarten
#   primary middle schools
#   secondary schools
#   independent schools private education
#   faith religious schools
#  higher education tertiary education
#   colleges education
#   colleges higher education
#   universities
#   teacher training
#  adult education continuous learning
#  open learning home learning distance education
#  careers guidance
#   industrial vocational training
#  teaching specific groups persons special educational needs
#   teaching physically disabled students
#   teaching students specific learning difficulties needs
#   teaching students emotional behavioural difficulties
#   teaching gifted students
#   teaching students english second language tesol
#  teaching skills techniques
#  teaching specific subject
#   teachers classroom resources material
#  educational equipment technology computer-aided learning cal
#  extra-curricular activities
#   educational visits field trips
#  study learning skills general
# fiction
#  contemporary fiction
#  classics
#  crime
#   vintage crime
#   historical crime
#  thrillers
#   espionage
#   political legal
#  adventure
#   historical adventure
#   military fiction
#   westerns
#  horror
#   classic horror
#  science fiction
#   classic science fiction
#   space opera
#  fantasy
#  erotic fiction
#  myth legend told fiction
#  romance
#   adult contemporary romance
#   historical romance
#  sagas
#  historical fiction
#  religious spiritual fiction
#  graphic novels anime manga
#   graphic novels manga
#   graphic novels literary memoirs
#   graphic novels superheroes
#   graphic novels true stories non-fiction
#  fiction special features
#   short stories
#   fiction translation
#  fiction-related items
#   fiction companions
#   graphic novels history criticism
# stationery
#  miscellaneous items
# teen young adult
#  annuals anthologies poetry
#   annuals
#   anthologies
#   poetry
#  fiction
#   classics
#   general
#   adventure
#   horror ghost
#   science fiction
#   fantasy
#   traditional
#   romance
#   family
#   animal stories
#   humour
#   sports stories
#   school stories
#   historical
#   short stories
#   graphic novels
#   true stories
#  non-fiction
#   art
#   music
#   drama
#   television film
#   general knowledge
#   history
#   battles
#   work
#   people places
#   natural history
#   practical interests
#   religion beliefs
#   science
#   jokes humour
#   hobbies games
#   sport
#   mysteries supernatural childrens young adult
#  education
#   art design
#   music
#   english language
#   english literature
#   foreign languages
#   geography
#   history
#   mathematics numeracy
#   citizenship social education
#   religious studies
#   sciences
#   technology
#   business studies
#   physical education dance
#   general studies
#   study revision guides
#  reference
#   dictionaries
#   encyclopaedias
#   general reference
#   atlases
#  society social issues
#   health
#   bullying abuse
#   family issues
#   death bereavement
#   drugs addiction
#   disability
#   self-esteem
#   multiculturalism
#   relationships
#   school
#   social issues
# reference
#  encyclopaedias reference works
#   general encyclopaedias
#   reference works
#   geographical reference
#  world atlases world maps
#  library information sciences
#   library archive information management
#   automation library information processes
#   acquisitions collection development
#   bibliographic subject control
#   library information services
#   storage maintenance preservation collections
#  museums museology
#  research information general
#   information theory
#   data analysis general
#   coding theory cryptology
#   decision theory general
#   research methods general
#  interdisciplinary studies
#   regional studies
#   communication studies
#   semiotics semiology
#   development studies
#   general studies
#   peace studies conflict resolution
#   institutions learned societies general
# society social sciences
#  interdisciplinary studies
#   regional studies
#   communication studies
#   semiotics semiology
#   development studies
#   general studies
#   peace studies conflict resolution
#   institutions learned societies general
#  philosophy
#   history western philosophy
#   non-western philosophy
#   philosophy metaphysics ontology
#   philosophy epistemology theory knowledge
#   philosophy logic
#   philosophy mind
#   philosophy aesthetics
#   ethics moral philosophy
#   social political philosophy
#   popular philosophy
#  economics
#   economic theory philosophy
#   macroeconomics
#   microeconomics
#   economics industrial organisation
#   labour economics
#   economic growth
#   econometrics
#   economic forecasting
#   behavioural economics
#   international economics
#   development economics
#   environmental economics
#   political economy
#   health economics
#   welfare economics
#   economic systems structures
#   urban economics
#   financial crises disasters
#   economic history
#  society culture general
#   cultural studies
#   media studies
#   social issues processes
#   popular beliefs controversial knowledge
#   ethical issues debates
#   social groups
#  sociology anthropology
#   sociology
#   anthropology
#  social services welfare criminology
#   social welfare social services
#   crime criminology
#  psychology
#   psychological theory schools thought
#   psychological methodology
#   child developmental psychology
#   psychology ageing
#   family psychology
#   psychology gender
#   social group collective psychology
#   occupational industrial psychology
#   criminal forensic psychology
#   experimental psychology
#   physiological neuro-psychology biopsychology
#   abnormal psychology
#   psychology emotions
#   cognition cognitive psychology
#   self ego identity personality
#   states consciousness
#   sexual behaviour
#   parapsychological studies
#  teaching resources education
#   philosophy theory education
#   educational psychology
#   educational strategies policy
#   education care counselling students
#   organization management education
#   schools
#   higher education tertiary education
#   adult education continuous learning
#   open learning home learning distance education
#   careers guidance
#   teaching specific groups persons special educational needs
#   teaching skills techniques
#   teaching specific subject
#   educational equipment technology computer-aided learning cal
#   extra-curricular activities
#   study learning skills general
#  politics government
#   political science theory
#   comparative politics
#   political ideologies
#   political structure processes
#   political parties
#   public administration
#   central government
#   regional government
#   international relations
#   political control freedoms
#   political activism
#   political corruption
#  warfare defence
#   theory warfare military science
#   land forces warfare
#   naval forces warfare
#   air forces warfare
#   special elite forces
#   military administration
#   defence strategy planning research
#   war defence operations
#   weapons equipment
#   military life institutions
#   warfare defence issues
# business finance law
#  industry industrial studies
#   primary industries
#   energy industries utilities
#   manufacturing industries
#   transport industries
#   construction heavy industry
#   distributive industries
#   service industries
#   media information communication industries
#   civil service public sector
#   industrial relations safety
#  law
#   jurisprudence
#   international law
#   laws specific jurisdictions
#   law study revision guides
#  economics
#   economic theory philosophy
#   macroeconomics
#   microeconomics
#   economics industrial organisation
#   labour economics
#   economic growth
#   econometrics
#   economic forecasting
#   behavioural economics
#   international economics
#   development economics
#   environmental economics
#   political economy
#   health economics
#   welfare economics
#   economic systems structures
#   urban economics
#   financial crises disasters
#   economic history
#  finance accounting
#   accounting
#   finance
#  business management
#   business negotiation
#   business communication presentation
#   business mathematics systems
#   corporate governance responsibilities
#   sales marketing
#   operational research
#   organizational theory behaviour
#   ownership organization enterprises
#   office workplace
#   business studies general
#   business strategy
#   business innovation
#   e-commerce business aspects
#   business competition
#   business ethics
#   entrepreneurship
#   international business
#   consultancy grants businesses
#   management techniques

# %%
df_chars_clean = pd.DataFrame.from_records(
  data = list(count_chars(traverse_catalog(
    catalog,
    callback = lambda x, _: clean_title(get_title(x)),
  )).items()),
  columns = ('char', 'n'),
)
df_chars_cmp = (
  df_chars_original.merge(df_chars_clean, how='outer', on='char')
  .fillna(0)
  .astype({"n_y": int})
)
df_chars_cmp['n_diff'] = df_chars_cmp['n_y'] - df_chars_cmp['n_x']
df_chars_cmp[
     (df_chars_cmp['char'] < 'A')
  | ((df_chars_cmp['char'] > 'Z') & (df_chars_cmp['char'] < 'a'))
  |  (df_chars_cmp['char'] > 'z')
].sort_values('n_x', ascending=False)
# Out:
#    char   n_x   n_y  n_diff
# 8        5700  4212   -1488
# 17    &  1032     0   -1032
# 43    :   271     0    -271
# 37    ,   269     0    -269
# 42    -   117   111      -6
# 61    0   115    11    -104
# 50    (    91     0     -91
# 51    )    91     0     -91
# 21    /    80     0     -80
# 58    1    50     4     -46
# 64    '    23     0     -23
# 67    5    16     0     -16
# 59    2    15    12      -3
# 69    9    14     1     -13
# 65    6    10     1      -9
# 68    8     8     0      -8
# 60    3     8     4      -4
# 66    7     6     0      -6
# 70    4     5     0      -5
# 62    .     1     1       0

# %%
df_chars_wn = pd.DataFrame.from_records(
  data    = list(count_chars(wn.all_lemma_names()).items()),
  columns = ('char', 'n'),
)
df_chars_wn[
     (df_chars_wn['char'] < 'A')
  | ((df_chars_wn['char'] > 'Z') & (df_chars_wn['char'] < 'a'))
  |  (df_chars_wn['char'] > 'z')
].sort_values('n', ascending=False)
# Out:
#    char      n
# 10    _  76399
# 2     -   7655
# 39    '   1303
# 0     .    603
# 16    1    274
# 15    0    169
# 1     2    151
# 13    4    108
# 14    5    105
# 11    3     97
# 12    8     87
# 24    9     76
# 22    6     75
# 23    7     72
# 40    /     16

# %%
wn_complex_lemmas_stats = dict()

for lemma in wn.all_lemma_names():
  chunks   = split_token(lemma)
  chunks_n = len(chunks)
  if chunks_n > 1:
    wn_complex_lemmas_stats[chunks_n] = wn_complex_lemmas_stats.setdefault(chunks_n, 0) + 1

df_chunks_wn = pd.DataFrame.from_records(
  data    = list(wn_complex_lemmas_stats.items()),
  columns = ('chunk_len', 'n'),
)
df_chunks_wn.sort_values('n', ascending=False)
# Out:
#    chunk_len      n
# 0          2  57758
# 1          3   9406
# 3          4   1751
# 2          5    342
# 5          6     89
# 4          7     27
# 6          8     24
# 7          9     11

# %%
too_complex_lemmas = dict[int, set]()

for lemma in wn.all_lemma_names():
  chunks   = split_token(lemma)
  chunks_n = len(chunks)
  if chunks_n >= 5:
    too_complex_lemmas.setdefault(chunks_n, set()).add(lemma)

for chunks_n in sorted(too_complex_lemmas, reverse=True):
  lemmas = ', '.join(sorted(too_complex_lemmas[chunks_n]))
  print(f"{chunks_n}: {lemmas}")
# Out:
# 9: abul-walid_mohammed_ibn-ahmad_ibn-mohammed_ibn-roshd, american_federation_of_labor_and_congress_of_industrial_organizations, cooper_union_for_the_advancement_of_science_and_art, first_epistle_of_paul_the_apostle_to_the_corinthians, first_epistle_of_paul_the_apostle_to_the_thessalonians, international_islamic_front_for_jihad_against_jews_and_crusaders, popular_front_for_the_liberation_of_palestine-general_command, prayer_of_azariah_and_song_of_the_three_children, second_epistle_of_paul_the_apostle_to_the_corinthians, second_epistle_of_paul_the_apostle_to_the_thessalonians, united_nations_office_for_drug_control_and_crime_prevention
# 8: abu_ali_al-husain_ibn_abdallah_ibn_sina, al-jama'a_al-islamiyyah_al-muqatilah_bi-libya, armenian_secret_army_for_the_liberation_of_armenia, baron_friedrich_wilhelm_ludolf_gerhard_augustin_von_steuben, baronne_anne_louise_germaine_necker_de_steal-holstein, blood-oxygenation_level_dependent_functional_magnetic_resonance_imaging, church_of_jesus_christ_of_latter-day_saints, economic_commission_for_asia_and_the_far_east, epistle_of_paul_the_apostle_to_the_colossians, epistle_of_paul_the_apostle_to_the_ephesians, epistle_of_paul_the_apostle_to_the_galatians, epistle_of_paul_the_apostle_to_the_philippians, epistle_of_paul_the_apostle_to_the_romans, first_epistle_of_paul_the_apostle_to_timothy, food_and_agriculture_organization_of_the_united_nations, juan_carlos_victor_maria_de_borbon_y_borbon, lautaro_faction_of_the_united_popular_action_movement, marie_joseph_paul_yves_roch_gilbert_du_motier, popular_democratic_front_for_the_liberation_of_palestine, right_to_speedy_and_public_trial_by_jury, royal_society_of_london_for_improving_natural_knowledge, second_epistle_of_paul_the_apostle_to_timothy, united_kingdom_of_great_britain_and_northern_ireland, united_society_of_believers_in_christ's_second_appearing
# 7: 5-hydroxy-3-methylglutaryl-coenzyme_a_reductase, academy_of_motion_picture_arts_and_sciences, association_for_the_advancement_of_retired_persons, baron_de_la_brede_et_de_montesquieu, baron_karl_maria_friedrich_ernst_von_weber, basal_body_temperature_method_of_family_planning, democratic_front_for_the_liberation_of_palestine, democratic_republic_of_sao_tome_and_principe, earnings_before_interest_taxes_depreciation_and_amortization, epistle_of_paul_the_apostle_to_philemon, epistle_of_paul_the_apostle_to_titus, harakat_al-jihad_al-islami_al-filastini, islamic_jihad_for_the_liberation_of_palestine, let_the_cat_out_of_the_bag, naked_as_the_day_one_was_born, naked_as_the_day_you_were_born, national_association_of_securities_dealers_automated_quotations, order_of_our_lady_of_mount_carmel, organization_for_the_prohibition_of_chemical_weapons, paul_ludwig_von_beneckendorff_und_von_hindenburg, popular_front_for_the_liberation_of_palestine, prince_klemens_wenzel_nepomuk_lothar_von_metternich, secretary_of_state_for_the_home_department, ship-towed_long-range_acoustic_detection_system, united_nations_crime_prevention_and_criminal_justice, united_nations_educational_scientific_and_cultural_organization, wisdom_of_jesus_the_son_of_sirach
# 6: academy_of_television_arts_and_sciences, air_force_intelligence_surveillance_and_reconnaissance, alexis_charles_henri_maurice_de_tocqueville, american_standard_code_for_information_interchange, army_for_the_liberation_of_rwanda, army_high_performance_computing_research_center, association_of_islamic_groups_and_communities, attorney_general_of_the_united_states, bachelor_of_arts_in_library_science, baron_friedrich_heinrich_alexander_von_humboldt, baron_hermann_ludwig_ferdinand_von_helmholtz, battle_of_the_chemin-des-dames, beyond_a_shadow_of_a_doubt, breach_of_the_covenant_of_warranty, breach_of_trust_with_fraudulent_intent, bureau_of_alcohol_tobacco_and_firearms, center_for_disease_control_and_prevention, characteristic_root_of_a_square_matrix, charles_andre_joseph_marie_de_gaulle, commission_on_the_status_of_women, comte_donatien_alphonse_francois_de_sade, conte_alessandro_giuseppe_antonio_anastasio_volta, court_of_assize_and_nisi_prius, democratic_and_popular_republic_of_algeria, democratic_socialist_republic_of_sri_lanka, department_of_health_and_human_services, department_of_health_education_and_welfare, department_of_housing_and_urban_development, diego_rodriguez_de_silva_y_velazquez, don_luchino_visconti_conte_di_modrone, edmond_louis_antoine_huot_de_goncourt, fahd_ibn_abdel_aziz_al-saud, faisal_ibn_abdel_aziz_al-saud, federal_islamic_republic_of_the_comoros, federation_of_saint_kitts_and_nevis, first_of_october_antifascist_resistance_group, francisco_jose_de_goya_y_lucientes, freedom_from_cruel_and_unusual_punishment, gates_of_the_arctic_national_park, general_agreement_on_tariffs_and_trade, george_louis_palmella_busson_du_maurier, georges_leopold_chretien_frederic_dagobert_cuvier, great_seal_of_the_united_states, have_a_bun_in_the_oven, henri_rene_albert_guy_de_maupassant, human_t-cell_leukemia_virus-1, imaginary_part_of_a_complex_number, immaculate_conception_of_the_virgin_mary, independent_state_of_papua_new_guinea, international_bank_for_reconstruction_and_development, iz_al-din_al-qassam_battalions, keep_one's_nose_to_the_grindstone, keep_one's_shoulder_to_the_wheel, kiss-me-over-the-garden-gate, lucy_in_the_sky_with_diamonds, master_of_arts_in_library_science, medical_literature_analysis_and_retrieval_system, million_floating_point_operations_per_second, national_institute_of_standards_and_technology, naval_air_warfare_center_weapons_division, oblique_vein_of_the_left_atrium, on_the_spur_of_the_moment, organization_of_the_oppressed_on_earth, posterior_vein_of_the_left_ventricle, prince_otto_eduard_leopold_von_bismarck, pull_the_wool_over_someone's_eyes, racketeer_influenced_and_corrupt_organizations_act, respiratory_distress_syndrome_of_the_newborn, revelation_of_saint_john_the_divine, right_to_the_pursuit_of_happiness, salafast_group_for_call_and_combat, salah-ad-din_yusuf_ibn-ayyub, sao_thome_e_principe_monetary_unit, secretary_of_health_and_human_services, secretary_of_health_education_and_welfare, secretary_of_housing_and_urban_development, seven_wonders_of_the_ancient_world, supreme_court_of_the_united_states, take_the_bull_by_the_horns, theophrastus_philippus_aureolus_bombastus_von_hohenheim, trillion_floating_point_operations_per_second, united_nations_international_children's_emergency_fund, united_self-defense_force_of_colombia, united_self-defense_group_of_colombia, united_states_army_criminal_investigation_laboratory, united_states_fish_and_wildlife_service, united_states_national_library_of_medicine, vice_president_of_the_united_states, war_of_the_league_of_augsburg
# 5: 1st_earl_baldwin_of_bewdley, 1st_viscount_montgomery_of_alamein, abu_hafs_al-masri_brigades, advanced_research_and_development_activity, al-hasan_ibn_al-haytham, albert_francis_charles_augustus_emmanuel, albrecht_eusebius_wenzel_von_wallenstein, alessandro_di_mariano_dei_filipepi, antonio_lopez_de_santa_ana, antonio_lopez_de_santa_anna, apex_of_the_sun's_way, arcuate_artery_of_the_kidney, arcuate_vein_of_the_kidney, artery_of_the_penis_bulb, artery_of_the_vestibule_bulb, as_a_matter_of_fact, as_luck_would_have_it, association_of_southeast_asian_nations, bachelor_of_arts_in_nursing, bachelor_of_science_in_architecture, bachelor_of_science_in_engineering, baron_hugh_caswall_tremenheere_dowding, baron_jean_baptiste_joseph_fourier, baron_karl_wilhelm_von_humboldt, baron_lloyd_webber_of_sydmonton, baron_richard_von_krafft-ebing, basic_point_defense_missile_system, battle_of_monmouth_court_house, battle_of_the_ardennes_bulge, battle_of_the_bismarck_sea, battle_of_the_coral_sea, battle_of_the_little_bighorn, battle_of_the_philippine_sea, battle_of_the_spanish_armada, be-all_and_end-all, be_all_and_end_all, bernd_heinrich_wilhelm_von_kleist, black_and_gold_garden_spider, blow_out_of_the_water, book_of_the_prophet_daniel, boy_orator_of_the_platte, bright_as_a_new_penny, buffalo_bill's_wild_west_show, bureau_of_engraving_and_printing, bureau_of_intelligence_and_research, by_hook_or_by_crook, calendar_method_of_birth_control, canary_island_hare's_foot_fern, cape_of_good_hope_province, capital_of_antigua_and_barbuda, capital_of_papua_new_guinea, capital_of_serbia_and_montenegro, capital_of_the_dominican_republic, capital_of_the_russian_federation, capital_of_the_united_kingdom, capital_of_the_united_states, capital_of_trinidad_and_tobago, central_artery_of_the_retina, central_vein_of_suprarenal_gland, centre_for_international_crime_prevention, cervical_glands_of_the_uterus, character-at-a-time_printer, circumflex_artery_of_the_thigh, co-operative_republic_of_guyana, cockcroft_and_walton_voltage_multiplier, combination_in_restraint_of_trade, come_hell_or_high_water, come_out_of_the_closet, compact_disc_read-only_memory, constitution_of_the_united_states, coronoid_process_of_the_mandible, council_of_basel-ferrara-florence, count_nikolaus_ludwig_von_zinzendorf, criminal_intelligence_services_of_canada, dag_hjalmar_agne_carl_hammarskjold, dalton's_law_of_partial_pressures, dame_agatha_mary_clarissa_christie, dame_kiri_janette_te_kanawa, day_in_and_day_out, dead_hand_of_the_past, defense_advanced_research_projects_agency, defense_reutilization_and_marketing_service, democratic_people's_republic_of_korea, democratic_republic_of_the_congo, department_of_commerce_and_labor, department_of_defense_laboratory_system, department_of_the_federal_government, directorate_for_inter-services_intelligence, disease_of_the_neuromuscular_junction, double_standard_of_sexual_behavior, duke_of_argyll's_tea_tree, ear-nose-and-throat_doctor, economic_and_social_council_commission, economic_commission_for_latin_america, edward_george_earle_bulwer-lytton, eigenvalue_of_a_square_matrix, einstein's_general_theory_of_relativity, einstein's_special_theory_of_relativity, empire_state_of_the_south, enzyme-linked-immunosorbent_serologic_assay, equal_protection_of_the_laws, erasable_programmable_read-only_memory, esther_hobart_mcquigg_slack_morris, evelyn_arthur_saint_john_waugh, executive_office_of_the_president, false_lily_of_the_valley, feast_of_the_unleavened_bread, federal_democratic_republic_of_ethiopia, federal_home_loan_bank_system, federal_home_loan_mortgage_corporation, federal_law_enforcement_training_center, feel_like_a_million_dollars, ferdinand_joseph_la_menthe_morton, fibrocystic_disease_of_the_breast, fibrocystic_disease_of_the_pancreas, field-sequential_color_television_system, field-sequential_color_tv_system, filet_de_boeuf_en_croute, first_baron_marks_of_broughton, first_baron_rutherford_of_nelson, first_earl_kitchener_of_khartoum, first_epistle_to_the ...

# %%
title_tokens_original   = set()
title_tokens_original_n = 0
title_tokens_original_hit_n = 0
title_tokens_original_hit_ratio = 0

for s in traverse_catalog(
  catalog,
  callback = lambda x, _: clean_title(get_title(x)),
):
  t = word_tokenize(s)
  for x in t:
    if x not in title_tokens_original:
      title_tokens_original.add(x)
      is_hit = len(wn.synsets(x)) > 0 
      if is_hit:
        title_tokens_original_hit_n += 1

title_tokens_original_n = len(title_tokens_original)
title_tokens_original_hit_ratio = title_tokens_original_hit_n / title_tokens_original_n
title_tokens_original.clear()

print("original title tokens hit ratio: {:.3f}% ({:} / {:})".format(
  title_tokens_original_hit_ratio * 100,
  title_tokens_original_hit_n,
  title_tokens_original_n,
))
# Out:
# original title tokens hit ratio: 93.191% (2409 / 2585)

# %%
wn_n_original = 0
wn_lemmatized = set()
wn_stemmed    = set()

lemmatize = WordNetLemmatizer().lemmatize
stem      = PorterStemmer().stem

for lemma in wn.all_lemma_names():
  wn_n_original += 1  
  lemmatized = [lemmatize(t) for t in split_token(lemma)]
  stemmed    = [stem(t) for t in lemmatized]

  wn_lemmatized.add("".join(lemmatized))
  wn_stemmed.add("".join(stemmed))

wn_n_lemmatized = len(wn_lemmatized)
wn_n_stemmed    = len(wn_stemmed)

wn_lemmatized.clear()
wn_stemmed.clear()

# %%
print(f"wn N original: {wn_n_original}")

wn_n_lemmatized_delta       = wn_n_original - wn_n_lemmatized
wn_n_lemmatized_delta_ratio = wn_n_lemmatized_delta / wn_n_original
print(f"wn N lemmatized: {wn_n_lemmatized}, Δ: {wn_n_lemmatized_delta_ratio*100:.3f}% ({wn_n_lemmatized_delta})")

wn_n_stemmed_delta       = wn_n_original - wn_n_stemmed
wn_n_stemmed_delta_ratio = wn_n_stemmed_delta / wn_n_original
print(f"wn N stemmed: {wn_n_stemmed}, Δ: {wn_n_stemmed_delta_ratio*100:.3f}% ({wn_n_stemmed_delta})")
# Out:
# wn N original: 147306
# wn N lemmatized: 145946, Δ: 0.923% (1360)
# wn N stemmed: 127513, Δ: 13.437% (19793)

# %%
wn_lemmas_clean = dict()

for lemma in wn.all_lemma_names():  
  lemmatized = [lemmatize(t) for t in split_token(lemma)]
  stemmed    = [stem(t) for t in lemmatized]
  
  key1 = lemma
  key2 = "".join(lemmatized)
  key3 = "".join(stemmed)

  wn_lemmas_clean.setdefault(key1, set()).add(lemma)
  wn_lemmas_clean.setdefault(key2, set()).add(lemma)
  wn_lemmas_clean.setdefault(key3, set()).add(lemma)

# %%
title_tokens_clean_hit = set()
title_tokens_clean_not_hit = set()

for s in traverse_catalog(
  catalog,
  callback = lambda x, _: clean_title(get_title(x)),
):
  for token in word_tokenize(s):
    tokens = split_token(token)
    lemmatized = [lemmatize(t) for t in tokens]
    stemmed    = [stem(t) for t in lemmatized]    

    token2 = "".join(lemmatized)
    token3 = "".join(stemmed)

    if (
         token  in title_tokens_clean_hit
      or token2 in title_tokens_clean_hit
      or token3 in title_tokens_clean_hit
    ):
      continue

    if token in wn_lemmas_clean:
      title_tokens_clean_hit.add(token)
    elif token2 in wn_lemmas_clean:
      title_tokens_clean_hit.add(token2)
    elif token3 in wn_lemmas_clean:
      title_tokens_clean_hit.add(token3)
    else:      
      title_tokens_clean_not_hit.add(token)
  
  # TODO: consider subtokens as separate words
  # TODO: consider 2grams/3grams
  # TODO: consider subwords

title_tokens_clean_hit_n = len(title_tokens_clean_hit)
title_tokens_clean_not_hit_n = len(title_tokens_clean_not_hit)
title_tokens_clean_n = title_tokens_clean_hit_n + title_tokens_clean_not_hit_n
title_tokens_clean_hit_ratio = title_tokens_clean_hit_n / title_tokens_clean_n

print("clean title tokens hit ratio: {:.3f}% ({:} / {:})".format(
  title_tokens_clean_hit_ratio * 100,
  title_tokens_clean_hit_n,
  title_tokens_clean_n,
))
# Out:
# clean title tokens hit ratio: 94.118% (2208 / 2346)

# %%
it = iter(sorted(title_tokens_clean_not_hit))

# %%
v = next(it)
v, wn_lemmas_clean.get(v)
# Out:
# ('biomechanics', None)
